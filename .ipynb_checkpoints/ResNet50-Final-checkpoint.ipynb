# %% [markdown]
# # **Multi-classification Use Case for ResNet50**
#
# For supermarkets and other stores that sell fruits, it could be important to utilize computer vision to automate the inventory management process. Stores might need to periodically detect whether fruits are in good shape and whether some of them are misplaced to a different group.
# In this project, we explore how a mature model architecture may perform in this use case, with apples, bananas, and oranges, all of which might be fresh or rotten. The model mainly consists of ResNet50 with pre-trained parameters, connected with a flattened and a dropout layers.

# %% [markdown]
# # **1.Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import os

# %%
from google.colab import drive
drive.mount('/content/drive')

#data: https://drive.google.com/drive/folders/1JrRWbfaNl2EHXzObSPRCXlIThQRhxeI2?usp=sharing
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **2. Data Loading & Augmentation**
#
# In our project, we split the training set further into a set for training, and the other set for validation at each epoch.
#
# Important hyperparameters here are the batch size, input image size, and the validation split.

# %%
path = "/content/drive/MyDrive/HKSTP DTT /Mini Project/Computer Vision Final Project Files/dataset"

# %%
train_path = os.path.join(path, "train")
test_path = os.path.join(path, "test")

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rotation_range=75,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   fill_mode='nearest',
                                   validation_split=0.2) # Split 0.2 of the train data to validation data

# %%
Classes = ['freshapples', 'freshbanana','freshoranges','rottenapples', 'rottenbanana', 'rottenoranges']

# %%
# Separate train, validation and test set 
Batch_Size = 32

train_set = train_datagen.flow_from_directory(train_path,
                                              target_size=(224, 224),
                                              batch_size=Batch_Size,
                                              classes=Classes,
                                              subset='training') # Set as training data

validation_set = train_datagen.flow_from_directory(train_path, # Same directory as training data
                                                   target_size=(224, 224),
                                                   batch_size=Batch_Size,
                                                   classes=Classes,
                                                   subset='validation') # Set as validation data

test_set = ImageDataGenerator().flow_from_directory(test_path, 
                                                    target_size=(224,224), 
                                                    classes=Classes,
                                                    shuffle= False,
                                                    batch_size = Batch_Size)# Set as test data
# Out:
# Found 8739 images belonging to 6 classes.
# Found 2182 images belonging to 6 classes.
# Found 2698 images belonging to 6 classes.

# %% [markdown]
# Now we tally the class-wise numbers of images under training, validation, and test sets.

# %%
print ("In train_set ")
for i in range(len (train_set.class_indices)):
    print(Classes[i],":\t",list(train_set.classes).count(i))
print ("") 

print ("In validation_set ")
for i in range(len (validation_set.class_indices)):
    print(Classes[i],":\t",list(validation_set.classes).count(i))
print ("") 

print ("In test_set ")
for i in range(len (test_set.class_indices)):
    print(Classes[i],":\t",list(test_set.classes).count(i))
# Out:
# In train_set
# freshapples :	 1355
# freshbanana :	 1281
# freshoranges :	 1173
# rottenapples :	 1874
# rottenbanana :	 1780
# rottenoranges :	 1276
#
# In validation_set
# freshapples :	 338
# freshbanana :	 320
# freshoranges :	 293
# rottenapples :	 468
# rottenbanana :	 444
# rottenoranges :	 319
#
# In test_set
# freshapples :	 395
# freshbanana :	 381
# freshoranges :	 388
# rottenapples :	 601
# rottenbanana :	 530
# rottenoranges :	 403

# %% [markdown]
# ### **3. Model Construction & Training**
#
# Our model relies vastly on the pre-constructed and pre-trained ResNet50.
#
# We construct the entire model as normal. The connection is loaded data -> ResNet50 -> Flatten -> Dropout(0.5) -> Output. After the construction, we freeze the top 2 layers of ResNet50 before compiling.
#
# A noticeable difference of our model is that we train the transfer learning model all at once, unlike the freeze-train-unfreeze-train procedure we studied in class. Moreover, we also limit the steps per training epoch and per validation epoch to speed up runtime.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout

# %%
image_size = (224, 224, 3)
freeze_layers = 2
num_epochs = 5

# %%
# Data is ready to be run into the base model, ResNet50, after being loaded & augmented
classifier = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_tensor=None,
               input_shape=image_size)

x = classifier.output
x = Flatten()(x)
# Dropout layer
x = Dropout(0.5)(x)
# Dense layer
output_layer = Dense(len(Classes), activation='softmax', name='softmax')(x)
# Out:
# ...
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
# Freeze some layers on top before compiling, with the number of layers as a h-param
new_classifier = Model(inputs=classifier.input, outputs=output_layer)
for layer in new_classifier.layers[:freeze_layers]:
    layer.trainable = False
for layer in new_classifier.layers[freeze_layers:]:
    layer.trainable = True

# %% [markdown]
# Now we conduct model compilation and training.
#
# Surprisingly, even setting a low learning rate of 0.0001, the accuracy manages to climb from about 0.2 to 0.7 during the first epoch, and from 0.7 to 0.88 during the second epoch.

# %%
# Complie the model
new_classifier.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0001),
                  loss='categorical_crossentropy', metrics=['accuracy'])

new_classifier.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %% [markdown]
# Visualizing the layers

# %%
pip install git+https://github.com/paulgavrikov/visualkeras
# Out:
# ...
#   Cloning https://github.com/paulgavrikov/visualkeras to /tmp/pip-req-build-zcnlb_op
#   Running command git clone -q https://github.com/paulgavrikov/visualkeras /tmp/pip-req-build-zcnlb_op
# ...
#   Created wheel for visualkeras: filename=visualkeras-0.0.2-cp37-none-any.whl size=12975 sha256=2d77699e47fafe6ddd58cc75d8de31cdfcd77b5ab6922b5716345cecb9aafd47
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hbhtr3kz/wheels/63/ee/ff/e163fd012b516d0922da126313ce2133e97f712726dc4dc722
# Successfully built visualkeras

# %%
import visualkeras
from tensorflow.keras.layers import BatchNormalization, ZeroPadding2D, Activation, MaxPool2D

# Visualizing our model architecture
visualkeras.layered_view(new_classifier, 
                         legend=True, 
                         to_file='output.png',
                         type_ignore=[MaxPool2D,Activation,ZeroPadding2D,BatchNormalization,Dropout,Flatten])  # font is optional!
# Out:
# <PIL.Image.Image image mode=RGBA size=5232x1231 at 0x7F0986835C10>

# %%
# Train the model
history = new_classifier.fit(train_set,
                        steps_per_epoch = 50, # normally 274 (test_set // Batch_Size)
                        validation_data = validation_set,
                        validation_steps = 20, # normally 96 (validation_set // Batch_Size)
                        epochs = num_epochs)
# Out:
# Epoch 1/5
# 50/50 [==============================] - 46s 748ms/step - loss: 1.2536 - accuracy: 0.7088 - val_loss: 0.5687 - val_accuracy: 0.8781
# Epoch 2/5
# 50/50 [==============================] - 36s 723ms/step - loss: 0.3703 - accuracy: 0.9069 - val_loss: 0.2397 - val_accuracy: 0.9453
# Epoch 3/5
# 50/50 [==============================] - 36s 721ms/step - loss: 0.2187 - accuracy: 0.9394 - val_loss: 0.6370 - val_accuracy: 0.9297
# Epoch 4/5
# 50/50 [==============================] - 36s 728ms/step - loss: 0.2413 - accuracy: 0.9350 - val_loss: 0.2400 - val_accuracy: 0.9719
# Epoch 5/5
# 50/50 [==============================] - 36s 728ms/step - loss: 0.1810 - accuracy: 0.9494 - val_loss: 0.3803 - val_accuracy: 0.9594

# %%
# save the model 
model_path = "model-resnet50-trained.h5"
new_classifier.save(model_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# ### **4. Model Evaluation**
#
# After the training finishes, we run the validation and test data through the model to obtain loss function values and accuracy scores.
#
# This section also contains the single-image prediction algorithm and some visualizations on model performance.

# %%
# Validation accuracy
new_classifier.evaluate(validation_set)
# Out:
# 69/69 [==============================] - 32s 462ms/step - loss: 0.3574 - accuracy: 0.9620
# [0.3573806881904602, 0.9619615077972412]

# %%
# test accuracy
new_classifier.evaluate(test_set)
# Out:
# 85/85 [==============================] - 17s 193ms/step - loss: 0.1784 - accuracy: 0.9729
# [0.17842897772789001, 0.9729429483413696]

# %%
#New part to visualize the model

acc = history.history['accuracy'] # new change for TF changes
val_acc = history.history['val_accuracy'] # new change for TF changes

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(num_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Single-image Prediction**
#
# To realize this function, we create a dictionary that maps the file name of the image to its class name, so that after randomly drawing an image file, we can load and run the image through the model, and meanwhile retrieving the true label from the dictionary.

# %%
label_dict = test_set.class_indices  # we can match the label indices and their names
label_dict = {val:key for key, val in label_dict.items()}
label_dict
# Out:
# {0: 'freshapples',
#  1: 'freshbanana',
#  2: 'freshoranges',
#  3: 'rottenapples',
#  4: 'rottenbanana',
#  5: 'rottenoranges'}

# %%
from tensorflow.keras.models import load_model
classifier_model = load_model(model_path) # load the model

# %%
root_dir = test_path
folders = ['freshapples','freshbanana','freshoranges','rottenapples','rottenbanana','rottenoranges']
filenames = []
file_dict = {}

# Create the dictionary for mapping filename with label
for folder in folders:
  files = os.listdir(f'{root_dir}/{folder}')
  for fruit_img in files:
    filenames.append(fruit_img)
    file_dict[fruit_img] = folder

# %%
from keras.preprocessing import image

# %%
def Image_and_Prediction():
  # Randomly draw one image and print it out
  sample = np.random.choice(filenames)
  print(sample)
  folder_name = file_dict[sample]
  img_path = f'{root_dir}/{folder_name}/{sample}'
  img = image.load_img(img_path)
  plt.imshow(img)

  # Run the randomly drawn image through the model and get results 
  test_image = image.load_img(img_path, target_size=image_size)
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image,axis=0)
  result = classifier_model.predict(test_image).astype(int)
  result = [1 if x == max(list(result)[0]) else 0 for x in list(result)[0]]
  result_label = label_dict[list(result).index(1)] if 1 in list(result) else 'no prediction'
  print(list(result))
  print('predicted: ',result_label)
  print('true: ',folder_name)

# %%
Image_and_Prediction()
# Out:
# saltandpepper_Screen Shot 2018-06-12 at 11.33.50 PM.png
# [1, 1, 1, 1, 1, 1]
# predicted:  freshapples
# true:  rottenoranges

# %% [markdown]
# #### **Visualization of Model Performance**
#
# In this section, we plot a heatmap for the confusion matrix and print out the classification report so that we can have more insights into the model.
#
# When coding for this section, we didn't find any built-in function that produces confusion matrices in keras. Thus, we go back to the sci-kit learn library for that function.
#
# In order to sync the sequences of true labels and predicted labels, we iteratively append those labels by loading test images one-by-one from the folders. More efficient codes could be implemented for this function.

# %%
res_idx, res_lbl = [], []

for filename in filenames:
  folder_name = file_dict[filename]
  root_dir = "drive/MyDrive/Mini Project/Computer Vision Final Project Files/dataset/test"
  img_path = f'{root_dir}/{folder_name}/{filename}'
  test_image = image.load_img(img_path, target_size=image_size)
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image,axis=0)
  result = classifier_model.predict(test_image).astype(int)
  result = [1 if x == max(list(result)[0]) else 0 for x in list(result)[0]]
  result_idx = list(result).index(1)
  res_idx.append(result_idx)
  result_label = label_dict[list(result).index(1)] if 1 in list(result) else 'no prediction'
  res_lbl.append(result_label)

y_true = list(file_dict.values())
y_pred = res_lbl

# %%
# Print the classification report
from sklearn.metrics import confusion_matrix, classification_report
print('----------------CLASSIFICATION REPORT----------------')
print(classification_report(y_true, y_pred))
# Out:
# ----------------CLASSIFICATION REPORT----------------
#                precision    recall  f1-score   support
#
#   freshapples       0.42      1.00      0.59       395
#   freshbanana       1.00      0.98      0.99       381
#  freshoranges       1.00      0.27      0.42       388
#  rottenapples       0.99      0.80      0.88       601
#  rottenbanana       1.00      0.98      0.99       530
# rottenoranges       1.00      0.68      0.81       403
#
#      accuracy                           0.79      2698
#     macro avg       0.90      0.78      0.78      2698
#  weighted avg       0.91      0.79      0.80      2698

# %%
# Plot the confusion matrix
plt.figure(figsize=(17,9))
sns.heatmap(confusion_matrix(y_true, y_pred, normalize='true'),
            fmt='.1%',
            annot=True,
            cmap="Blues",
            xticklabels=folders,
            yticklabels=folders,
            annot_kws={"size": 14})
plt.title('Normalized Confusion Matrix', {'fontsize':18})
plt.yticks(np.arange(6)+0.5,rotation=0, fontsize="12", va="center")
plt.xticks(np.arange(6)+0.5,rotation=0, fontsize="12", va="center")
# Out:
# ([<matplotlib.axis.XTick at 0x7f097e753f90>,
# ...
#  <a list of 6 Text major ticklabel objects>)
